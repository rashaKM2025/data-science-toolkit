# %%
print("welcome to data science")
# Out:
# welcome to data science

# %%
x=5
print(x)
print("Value of x is:" , x)
print(type(x))
# Out:
# 5
# Value of x is: 5
# <class 'int'>

# %%
y="oi"
print(y)
print(y + y)
# Out:
# oi
# oioi

# %%
print(4 != 5)
# Out:
# True

# %%
 x  = 'abcde'
 print(type(x)) # get the datatype
 print(x)
x = 'my name is shah'
print(f'the char {x[2]}') #indexing in python starts zero
print(f'The length of the string x is :{len(x)}') #prints the length of the string
# Out:
# <class 'str'>
# abcde
# the char
# The length of the string x is :15

# %%
message = '''Hello Rasha,
Welcome to Python!
Enjoy coding.'''
print(message)
# Out:
# Hello Rasha,
# Welcome to Python!
# Enjoy coding.

# %%
n = '''nani gore nani hahahahahahhahn ni kakak'''
print(n)
# Out:
# nani gore nani hahahahahahhahn ni kakak

# %%
n = '''nani, gore, nani hahahahahahhahn ni kakak'''
print(n)
# Out:
# nani, gore, nani hahahahahahhahn ni kakak

# %%
m = '''ayo
jaga
jakarta'''
print(m)
# Out:
# ayo
# jaga
# jakarta
